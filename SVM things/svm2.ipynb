# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics

# %%
df = pd.read_csv(r"heart.csv")
df.shape
# Out:
# (303, 14)

# %%
X = df.drop(['output'], axis=1)
Y = df['output']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
#Create a svm Classifier
ml = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
ml.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = ml.predict(x_test)
print("** Linear kernel **")
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Model Accuracy: how often is the classifier correct?
ml.score(x_test,y_test)

# Predict on the training set
y_train_pred = ml.predict(x_train)

# Predict on the testing set
y_test_pred = ml.predict(x_test)

# Calculate training accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy)

# Calculate testing accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy)

cm = confusion_matrix(y_test, y_test_pred)
print("Confusion Matrix:")
print(cm)
 
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()


precision = precision_score(y_test, y_test_pred)
print("Precision:", precision)

recall = recall_score(y_test, y_test_pred)
print("Recall:", recall)

f1 = f1_score(y_test, y_test_pred)
print("F1 Score:", f1)
# Out:
# ** Linear kernel **
# Accuracy: 0.8688524590163934
# Training Accuracy: 0.8636363636363636
# Testing Accuracy: 0.8688524590163934
# Confusion Matrix:
# [[25  4]
#  [ 4 28]]
# Precision: 0.875
# Recall: 0.875
# F1 Score: 0.875

# %%
#Create a svm Classifier
ml2 = svm.SVC(kernel='poly') # Linear Kernel

#Train the model using the training sets
ml2.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = ml2.predict(x_test)
print("** Polynomial kernel **")
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Model Accuracy: how often is the classifier correct?
ml2.score(x_test,y_test)

# Predict on the training set
y_train_pred = ml2.predict(x_train)

# Predict on the testing set
y_test_pred = ml2.predict(x_test)

# Calculate training accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy)

# Calculate testing accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy)

cm = confusion_matrix(y_test, y_test_pred)
print("Confusion Matrix:")
print(cm)
 
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()


precision = precision_score(y_test, y_test_pred)
print("Precision:", precision)

recall = recall_score(y_test, y_test_pred)
print("Recall:", recall)

f1 = f1_score(y_test, y_test_pred)
print("F1 Score:", f1)
# Out:
# ** Polynomial kernel **
# Accuracy: 0.7704918032786885
# Training Accuracy: 0.6611570247933884
# Testing Accuracy: 0.7704918032786885
# Confusion Matrix:
# [[20  9]
#  [ 5 27]]
# Precision: 0.75
# Recall: 0.84375
# F1 Score: 0.7941176470588235

# %%
#Create a svm Classifier
ml3 = svm.SVC(kernel='rbf') # Linear Kernel

#Train the model using the training sets
ml3.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = ml3.predict(x_test)
print("**RBF kernel**")
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Model Accuracy: how often is the classifier correct?
ml3.score(x_test,y_test)

# Predict on the training set
y_train_pred = ml3.predict(x_train)

# Predict on the testing set
y_test_pred = ml3.predict(x_test)

# Calculate training accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy)

# Calculate testing accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy)

cm = confusion_matrix(y_test, y_test_pred)
print("Confusion Matrix:")
print(cm)
 
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()


precision = precision_score(y_test, y_test_pred)
print("Precision:", precision)

recall = recall_score(y_test, y_test_pred)
print("Recall:", recall)

f1 = f1_score(y_test, y_test_pred)
print("F1 Score:", f1)
# Out:
# **RBF kernel**
# Accuracy: 0.7049180327868853
# Training Accuracy: 0.6570247933884298
# Testing Accuracy: 0.7049180327868853
# Confusion Matrix:
# [[15 14]
#  [ 4 28]]
# Precision: 0.6666666666666666
# Recall: 0.875
# F1 Score: 0.7567567567567567
