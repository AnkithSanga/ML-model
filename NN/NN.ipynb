# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"heart.csv")
df.shape
# Out:
# (303, 14)

# %%
X = df.drop(['output'], axis=1)
Y = df['output']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_train_scaled
# Out:
# array([[-1.35679832,  0.72250438,  0.00809909, ...,  0.95390513,
#         -0.68970073, -0.50904773],
#        [ 0.38508599,  0.72250438, -0.97189094, ...,  0.95390513,
#         -0.68970073,  1.17848036],
#        [-0.92132724,  0.72250438,  0.98808912, ..., -0.69498803,
#         -0.68970073, -0.50904773],
#        ...,
#        [ 1.58263146,  0.72250438,  1.96807914, ..., -0.69498803,
#          0.32186034, -0.50904773],
#        [-0.92132724,  0.72250438, -0.97189094, ...,  0.95390513,
#         -0.68970073,  1.17848036],
#        [ 0.92942484, -1.38407465,  0.00809909, ...,  0.95390513,
#          1.33342142, -0.50904773]])

# %%
X_test_scaled = scaler.fit_transform(X_test)
X_test_scaled
# Out:
# array([[ 3.51938054e-01,  5.20416500e-01, -8.17224232e-01,
#          6.92350698e-01,  6.70698758e-01, -5.45776823e-01,
#         -8.61891607e-01, -1.43822060e+00,  1.28536917e+00,
#         -3.99335669e-01, -4.85744493e-01,  7.31507170e-02,
#         -2.00597821e+00],
#        [ 5.85288285e-01,  5.20416500e-01,  2.00451227e+00,
#          1.72875297e+00,  9.21953360e-01, -5.45776823e-01,
#         -8.61891607e-01,  4.50638062e-01, -7.77986605e-01,
#         -6.92823330e-01, -4.85744493e-01, -8.19288030e-01,
#          9.42568077e-01],
#        [ 3.51938054e-01,  5.20416500e-01,  1.06393343e+00,
#          6.92350698e-01, -2.46998376e+00,  1.83225076e+00,
#          1.16023870e+00,  1.01327681e+00, -7.77986605e-01,
#         -6.92823330e-01,  1.07375098e+00,  7.31507170e-02,
#          9.42568077e-01],
#        [ 2.35262938e-01, -1.92153785e+00, -8.17224232e-01,
#         -1.36771119e-01,  3.45543726e+00, -5.45776823e-01,
#         -8.61891607e-01,  8.89417229e-02,  1.28536917e+00,
#          5.54499228e-01, -4.85744493e-01,  9.65589464e-01,
#          9.42568077e-01],
#        [ 1.98538967e+00, -1.92153785e+00,  1.06393343e+00,
#         -1.38045385e+00,  4.40382040e-01,  1.83225076e+00,
#         -8.61891607e-01, -7.14827921e-01, -7.77986605e-01,
#         -8.39567160e-01,  1.07375098e+00,  7.31507170e-02,
#         -5.31705069e-01],
#        [ 3.51938054e-01,  5.20416500e-01,  1.06393343e+00,
#          6.92350698e-01, -1.59059265e+00, -5.45776823e-01,
#          1.16023870e+00,  1.05346530e+00, -7.77986605e-01,
#          3.34383482e-01,  1.07375098e+00, -8.19288030e-01,
#         -5.31705069e-01],
#        [-9.31488218e-01, -1.92153785e+00, -8.17224232e-01,
#          7.05093349e-02, -2.02513955e-02, -5.45776823e-01,
#         -8.61891607e-01,  1.69318687e-01,  1.28536917e+00,
#         -8.39567160e-01, -4.85744493e-01, -8.19288030e-01,
#         -5.31705069e-01],
#        [ 2.35262938e-01, -1.92153785e+00, -8.17224232e-01,
#          3.28335638e+00,  9.21953360e-01,  1.83225076e+00,
#         -8.61891607e-01, -5.94262474e-01,  1.28536917e+00,
#          2.09530945e+00, -2.04523997e+00,  9.65589464e-01,
#          9.42568077e-01],
#        [ 1.91270681e-03,  5.20416500e-01, -8.17224232e-01,
#         -7.58612483e-01,  8.80077593e-01, -5.45776823e-01,
#          1.16023870e+00,  6.11391991e-01, -7.77986605e-01,
#         -8.39567160e-01,  1.07375098e+00, -8.19288030e-01,
#         -5.31705069e-01],
#        [ 1.63536433e+00,  5.20416500e-01, -8.17224232e-01,
#          3.81430016e-01, -1.06714557e+00,  1.83225076e+00,
#          1.16023870e+00, -2.72754617e-01, -7.77986605e-01,
#          1.65507796e+00, -4.85744493e-01,  9.65589464e-01,
#          9.42568077e-01],
#        [ 7.01963401e-01,  5.20416500e-01, -8.17224232e-01,
#          4.33250130e-01,  7.96326059e-01, -5.45776823e-01,
#         -8.61891607e-01, -2.32566135e-01,  1.28536917e+00,
#          1.21484646e+00, -4.85744493e-01,  9.65589464e-01,
#          9.42568077e-01],
#        [-4.64787756e-01,  5.20416500e-01, -8.17224232e-01,
#          6.92350698e-01, -2.02513955e-02, -5.45776823e-01,
#         -8.61891607e-01, -7.95204885e-01, -7.77986605e-01,
#          1.06810263e+00, -4.85744493e-01, -8.19288030e-01,
#          9.42568077e-01]])

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (2.12.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: packaging in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: setuptools in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.5.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: jax>=0.3.15 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nhi623\appdata\local\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# WARNING: Ignoring invalid distribution -andas (c:\users\nhi623\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\nhi623\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\nhi623\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\nhi623\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\nhi623\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\nhi623\appdata\local\anaconda3\lib\site-packages)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout, BatchNormalization

def model():
    model = Sequential()
    model.add(Dense(16, input_dim=13, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2)) 
    model.add(Dense(8, kernel_initializer='normal', activation='relu'))
    model.add(BatchNormalization())  
    model.add(Dense(4, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    adam = Adam(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

modell = model()

print(modell.summary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense
#       3 from tensorflow.keras.optimizers import Adam
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\__init__.py:476
#     474 if hasattr(_current_module, "keras"):
#     475   try:
# --> 476     _keras._load()
#     477   except ImportError:
#     478     pass
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\util\lazy_loader.py:41, in LazyLoader._load(self)
#      39 """Load the module and insert it into the parent's globals."""
#      40 # Import the target module and insert it into the parent's namespace
# ---> 41 module = importlib.import_module(self.__name__)
#      42 self._parent_module_globals[self._local_name] = module
#      44 # Emit a warning if one was specified
#
# File ~\AppData\Local\anaconda3\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\engine\functional.py:27
#      24 import tensorflow.compat.v2 as tf
#      26 from keras import backend
# ---> 27 from keras.dtensor import layout_map as layout_map_lib
#      28 from keras.engine import base_layer
#      29 from keras.engine import base_layer_utils
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\dtensor\layout_map.py:27
#      25 from keras.dtensor import lazy_variable
#      26 from keras.dtensor import utils
# ---> 27 from keras.engine import base_layer
#      29 # isort: off
#      30 from tensorflow.python.util.deprecation import deprecated
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\engine\base_layer.py:43
#      41 from keras.mixed_precision import loss_scale_optimizer
#      42 from keras.mixed_precision import policy
# ---> 43 from keras.saving.saved_model import layer_serialization
#      44 from keras.utils import generic_utils
#      45 from keras.utils import layer_utils
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\saving\saved_model\layer_serialization.py:22
#      20 from keras.saving.saved_model import base_serialization
#      21 from keras.saving.saved_model import constants
# ---> 22 from keras.saving.saved_model import save_impl
#      23 from keras.saving.saved_model import serialized_attributes
#      24 from keras.utils import generic_utils
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:34
#      32 from keras.saving import saving_utils
#      33 from keras.saving.saved_model import constants
# ---> 34 from keras.saving.saved_model import load as keras_load
#      35 from keras.saving.saved_model import serialized_attributes
#      36 from keras.saving.saved_model import utils
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\saving\saved_model\load.py:29
#      27 from keras.engine import input_spec
#      28 from keras.optimizers.optimizer_v2 import optimizer_v2
# ---> 29 from keras.protobuf import saved_metadata_pb2
#      30 from keras.protobuf import versions_pb2
#      31 from keras.saving import saving_utils
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\protobuf\saved_metadata_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from keras.protobuf import versions_pb2 as keras_dot_protobuf_dot_versions__pb2
#      19 DESCRIPTOR = _descriptor.FileDescriptor(
#      20   name='keras/protobuf/saved_metadata.proto',
#      21   package='third_party.py.keras.protobuf',
#    (...)
#      25   ,
#      26   dependencies=[keras_dot_protobuf_dot_versions__pb2.DESCRIPTOR,])
#      31 _SAVEDMETADATA = _descriptor.Descriptor(
#      32   name='SavedMetadata',
#      33   full_name='third_party.py.keras.protobuf.SavedMetadata',
#    (...)
#      58   serialized_end=175,
#      59 )
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\protobuf\versions_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='keras/protobuf/versions.proto',
#      20   package='third_party.py.keras.protobuf',
#    (...)
#      23   serialized_pb=_b('\n\x1dkeras/protobuf/versions.proto\x12\x1dthird_party.py.keras.protobuf\"K\n\nVersionDef\x12\x10\n\x08producer\x18\x01 \x01(\x05\x12\x14\n\x0cmin_consumer\x18\x02 \x01(\x05\x12\x15\n\rbad_consumers\x18\x03 \x03(\x05\x62\x06proto3')
#      24 )
#      29 _VERSIONDEF = _descriptor.Descriptor(
#      30   name='VersionDef',
#      31   full_name='third_party.py.keras.protobuf.VersionDef',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='producer', full_name='third_party.py.keras.protobuf.VersionDef.producer', index=0,
#      38       number=1, type=5, cpp_type=1, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='min_consumer', full_name='third_party.py.keras.protobuf.VersionDef.min_consumer', index=1,
#      45       number=2, type=5, cpp_type=1, label=1,
#      46       has_default_value=False, default_value=0,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50     _descriptor.FieldDescriptor(
#      51       name='bad_consumers', full_name='third_party.py.keras.protobuf.VersionDef.bad_consumers', index=2,
#      52       number=3, type=5, cpp_type=1, label=3,
#      53       has_default_value=False, default_value=[],
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=None, file=DESCRIPTOR),
#      57   ],
#      58   extensions=[
#      59   ],
#      60   nested_types=[],
#      61   enum_types=[
#      62   ],
#      63   serialized_options=None,
#      64   is_extendable=False,
#      65   syntax='proto3',
#      66   extension_ranges=[],
#      67   oneofs=[
#      68   ],
#      69   serialized_start=64,
#      70   serialized_end=139,
#      71 )
#      73 DESCRIPTOR.message_types_by_name['VersionDef'] = _VERSIONDEF
#      74 _sym_db.RegisterFileDescriptor(DESCRIPTOR)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\google\protobuf\descriptor.py:561, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     555 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     556             default_value, message_type, enum_type, containing_type,
#     557             is_extension, extension_scope, options=None,
#     558             serialized_options=None,
#     559             has_default_value=True, containing_oneof=None, json_name=None,
#     560             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561   _message.Message._CheckCalledFromGeneratedFile()
#     562   if is_extension:
#     563     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
modell.fit(X_train_scaled, y_train, epochs=150, batch_size=10, verbose = 1)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
pred = np.round(modell.predict(X_test_scaled)).astype(int)

print('Results for Model')
print('Accuracy: ', accuracy_score(y_test, pred))
print('Precision:', precision_score(y_test, pred))
print('Recall:', recall_score(y_test, pred))
cm = confusion_matrix(y_test, pred)
print("Confusion Matrix:")
print(cm)
# Out:
# 2/2 [==============================] - 0s 16ms/step
# Results for Model
# Accuracy:  0.8524590163934426
# Precision: 0.8285714285714286
# Recall: 0.90625
# Confusion Matrix:
# [[23  6]
#  [ 3 29]]
